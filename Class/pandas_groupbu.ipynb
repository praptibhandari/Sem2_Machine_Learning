# %%
import numpy as np
import pandas as pd

# %%
tip = pd.read_csv("/Users/praptibhandari/Desktop/machine learing/Data/tip.csv")
t = pd.read_csv("/Users/praptibhandari/Desktop/machine learing/Data/Titanic-Dataset.csv")

# %%
# how many bills on each day

tip.groupby("day").size()
# Out:
# day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# dtype: int64

# %%
#tip.group("day").size()

tip.groupby("day")["tip"].mean().round(2)
# Out:
# day
# Fri     2.73
# Sat     2.99
# Sun     3.26
# Thur    2.77
# Name: tip, dtype: float64
