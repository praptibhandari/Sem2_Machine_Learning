# %%
! pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/praptibhandari/Library/Python/3.9/lib/python/site-packages (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/praptibhandari/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/praptibhandari/Library/Python/3.9/lib/python/site-packages (from pandas) (2026.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/praptibhandari/Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/praptibhandari/Library/Python/3.9/lib/python/site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np

# %%
resturants_data = {
    'table_No': [12, 14, 15],
    'Bill_Amount': [1250, 890, 2400],
    'Waiter_Name': ['John', 'Smith', 'David']
}

df = pd.DataFrame(resturants_data)

print(df['Bill_Amount'])
print(type(df['Bill_Amount']))
# Out:
# 0    1250
# 1     890
# 2    2400
# Name: Bill_Amount, dtype: int64
# <class 'pandas.core.series.Series'>
